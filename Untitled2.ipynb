# %%
from sqlalchemy import create_engine, text

# %%
database_name = 'prescription_drugs'    # Fill this in with your lahman database name

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
import pandas as pd
import numpy

# %%
query = '''
SELECT *
FROM prescription
;
'''
with engine.connect() as connection:
    prescription = pd.read_sql(text(query), con = connection)

prescription
# Out:
#                  npi         drug_name  bene_count  total_claim_count  \
# 0       1.427076e+09    RALOXIFENE HCL         NaN               18.0
# 1       1.003858e+09       GLIMEPIRIDE         NaN               12.0
# 2       1.184627e+09    TAMSULOSIN HCL         NaN               14.0
# 3       1.306111e+09           SPIRIVA         NaN               13.0
# 4       1.285658e+09           SPIRIVA         NaN               13.0
# ...              ...               ...         ...                ...
# 656053  1.336170e+09  PROMETHAZINE HCL         NaN               11.0
# 656054  1.679676e+09    RANITIDINE HCL        53.0              178.0
# 656055  1.265588e+09          DIAZEPAM        16.0               48.0
# 656056  1.144212e+09          RAMIPRIL         NaN               38.0
# 656057  1.205923e+09          ATENOLOL        11.0               36.0
#
#         total_30_day_fill_count  total_day_supply  total_drug_cost  \
# ...

# %%
query = '''
SELECT *
FROM drug
;
'''
with engine.connect() as connection:
    drug = pd.read_sql(text(query), con = connection)

drug
# Out:
#                            drug_name                    generic_name  \
# 0           1ST TIER UNIFINE PENTIPS            PEN NEEDLE, DIABETIC
# 1      1ST TIER UNIFINE PENTIPS PLUS            PEN NEEDLE, DIABETIC
# 2                           ABACAVIR                ABACAVIR SULFATE
# 3                ABACAVIR-LAMIVUDINE     ABACAVIR SULFATE/LAMIVUDINE
# 4     ABACAVIR-LAMIVUDINE-ZIDOVUDINE  ABACAVIR/LAMIVUDINE/ZIDOVUDINE
# ...                              ...                             ...
# 3420                         ZYPREXA                      OLANZAPINE
# 3421                ZYPREXA RELPREVV              OLANZAPINE PAMOATE
# 3422                   ZYPREXA ZYDIS                      OLANZAPINE
# 3423                          ZYTIGA             ABIRATERONE ACETATE
# 3424                           ZYVOX                       LINEZOLID
#
#      opioid_drug_flag long_acting_opioid_drug_flag antibiotic_drug_flag  \
# ...

# %%
query='''

select drug_name,
sum(case when opioid_drug_flag='Y' then total_drug_cost end) as opioid_cost,
sum(case when opioid_drug_flag='N' then total_drug_cost end)as non_opioid_cost 
from drug 
inner join prescription  using(drug_name)
group by drug_name;

'''

with engine.connect() as connection:
    drug_group = pd.read_sql(text(query), con = connection)
drug_group
# Out:
#                            drug_name  opioid_cost  non_opioid_cost
# 0                     GLYCOPYRROLATE          NaN         93807.95
# 1                            VRAYLAR          NaN       1958755.51
# 2                IPRATROPIUM BROMIDE          NaN        756346.05
# 3                            ARANESP          NaN        687375.23
# 4                        CEFTAZIDIME          NaN          8949.90
# ...                              ...          ...              ...
# 1816                         NEVANAC          NaN         34844.88
# 1817                        BELSOMRA          NaN        838148.56
# 1818                       PRED MILD          NaN          2501.30
# 1819                         AVANDIA          NaN         70827.78
# 1820  NORETHINDRON-ETHINYL ESTRADIOL          NaN          2262.67
#
# [1821 rows x 3 columns]

# %%
total_opioid_cost=round(drug_group['opioid_cost'].sum(),2)
total_opioid_cost
# Out:
# 105080626.37

# %%
total_non_opioid_cost=round(drug_group['non_opioid_cost'].sum(),2)
total_non_opioid_cost
# Out:
# 3011133831.49

# %%
ratio=round((total_opioid_cost / total_non_opioid_cost),3)
print('Ratio of Opioid and non opioidcosts:', ratio)
# Out:
# Ratio of Opioid and non opioidcosts: 0.035

# %% [markdown]
# c. Are those who spend a higher ratio on opioids suffering from more deaths?

# %%
query = '''
SELECT *
FROM overdose_deaths
;
'''
with engine.connect() as connection:
    overdose_deaths = pd.read_sql(text(query), con = connection)

overdose_deaths
# Out:
#      overdose_deaths  year  fipscounty
# 0                135  2015       47157
# 1                150  2016       47157
# 2                159  2017       47157
# 3                123  2018       47157
# 4                122  2015       47093
# ..               ...   ...         ...
# 375                0  2018       47017
# 376                1  2015       47007
# 377                2  2016       47007
# 378                2  2017       47007
# 379                3  2018       47007
#
# [380 rows x 3 columns]

# %%
query='''
select sum(overdose_deaths) as deaths,fipscounty::int
from overdose_deaths
group by fipscounty;
'''
with engine.connect() as connection:
    overdose_deaths_county = pd.read_sql(text(query), con = connection)

overdose_deaths_county
# Out:
#     deaths  fipscounty
# 0        9       47097
# 1       46       47147
# 2       19       47107
# 3       22       47055
# 4       18       47103
# ..     ...         ...
# 90       7       47057
# 91       3       47033
# 92      80       47179
# 93      26       47117
# 94     683       47093
#
# [95 rows x 2 columns]

# %%
query='''
select sum(overdose_deaths) as deaths,year,fipscounty::int
from overdose_deaths
group by fipscounty,year;
'''
with engine.connect() as connection:
    overdose_deaths_county_year = pd.read_sql(text(query), con = connection)

overdose_deaths_county_year
# Out:
#      deaths  year  fipscounty
# 0        10  2016       47141
# 1         0  2016       47101
# 2        12  2016       47031
# 3         5  2017       47013
# 4         1  2017       47023
# ..      ...   ...         ...
# 375       2  2016       47085
# 376       3  2015       47171
# 377       4  2018       47185
# 378       1  2017       47057
# 379       1  2016       47181
#
# [380 rows x 3 columns]

# %%
query='''

select drug_name,fipscounty::int, 
sum(case when opioid_drug_flag='Y' then total_drug_cost end) as opioid_cost,
sum(case when opioid_drug_flag='N' then total_drug_cost end)as non_opioid_cost 
from drug 
inner join prescription  using(drug_name)
inner join prescriber  using (npi)
inner join zip_fips on prescriber.nppes_provider_zip5=zip_fips.zip
group by drug_name,fipscounty;

'''

with engine.connect() as connection:
    drug_group_county = pd.read_sql(text(query), con = connection)
drug_group_county
# Out:
#                          drug_name  fipscounty  opioid_cost  non_opioid_cost
# 0             ATORVASTATIN CALCIUM       47079          NaN        117006.58
# 1      DESVENLAFAXINE SUCCINATE ER       47145          NaN         15824.09
# 2              AMLODIPINE BESYLATE       47143          NaN         39891.28
# 3          TRIAMCINOLONE ACETONIDE       47163          NaN         56070.48
# 4                           DULERA       47179          NaN         79754.58
# ...                            ...         ...          ...              ...
# 60576                  FLOVENT HFA       47007          NaN         16326.86
# 60577                 KLOR-CON M15       47183          NaN           621.84
# 60578               AZELASTINE HCL       47035          NaN         17775.06
# 60579   CLOTRIMAZOLE-BETAMETHASONE       47017          NaN         10081.99
# 60580       ESOMEPRAZOLE MAGNESIUM       47097          NaN         26489.81
#
# [60581 rows x 4 columns]

# %%
cost_county=drug_group_county.groupby(['fipscounty'])['opioid_cost'].sum()
cost_county
# Out:
# fipscounty
# 9011       0.0
# 12097      0.0
# 13007      0.0
# 13027    599.4
# 13037      0.0
#          ...
# 48235      0.0
# 48257      0.0
# 48397      0.0
# 48451      0.0
# 48453    147.4
# Name: opioid_cost, Length: 114, dtype: float64

# %%
total_deaths_county=pd.merge(overdose_deaths_county_year,cost_county,how ='inner',on=['fipscounty'])

# %%
total_deaths_county
# Out:
#      deaths  year  fipscounty  opioid_cost
# 0        10  2016       47141   2666580.73
# 1        12  2015       47141   2666580.73
# 2        10  2017       47141   2666580.73
# 3         8  2018       47141   2666580.73
# 4         0  2016       47101    266016.26
# ..      ...   ...         ...          ...
# 375       2  2017       47027    380875.36
# 376       1  2016       47121    331246.22
# 377       2  2017       47121    331246.22
# 378       0  2018       47121    331246.22
# 379       0  2015       47121    331246.22
#
# [380 rows x 4 columns]

# %%
total_deaths_county.sort_values(by='deaths',ascending=False)
# Out:
#      deaths  year  fipscounty  opioid_cost
# 95      218  2018       47093  12687718.81
# 113     200  2018       47037  15498845.87
# 92      196  2017       47093  12687718.81
# 115     184  2017       47037  15498845.87
# 114     178  2016       47037  15498845.87
# ..      ...   ...         ...          ...
# 263       0  2016       47169   1352207.35
# 40        0  2017       47181    786064.46
# 170       0  2015       47097    142525.39
# 65        0  2015       47175    578980.94
# 379       0  2015       47121    331246.22
#
# [380 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(6, 6))
corr = total_deaths_county.corr(numeric_only=True)
cmap = sns.diverging_palette(220, 10, as_cmap=True)

mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, cmap=cmap, mask = mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
total_deaths=total_deaths_county[['deaths','opioid_cost']]
total_deaths
# Out:
#      deaths  opioid_cost
# 0        10   2666580.73
# 1        12   2666580.73
# 2        10   2666580.73
# 3         8   2666580.73
# 4         0    266016.26
# ..      ...          ...
# 375       2    380875.36
# 376       1    331246.22
# 377       2    331246.22
# 378       0    331246.22
# 379       0    331246.22
#
# [380 rows x 2 columns]

# %%
total_deaths.corr(numeric_only=True)
# Out:
#                deaths  opioid_cost
# deaths       1.000000     0.870156
# opioid_cost  0.870156     1.000000
