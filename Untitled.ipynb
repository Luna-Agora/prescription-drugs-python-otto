# %%
from sqlalchemy import create_engine, text

# %%
database_name = 'perscribers'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
import pandas as pd
import numpy as np

# %%
query = '''
SELECT county
     , year
     , overdose_deaths
     , population
FROM population
INNER JOIN fips_county
	ON population.fipscounty::int = fips_county.fipscounty::int
INNER JOIN overdose_deaths
	ON population.fipscounty::int = overdose_deaths.fipscounty::int
'''

with engine.connect() as connection:
    result = connection.execute(text(query))
    
with engine.connect() as connection:
    population = pd.read_sql(text(query), con = connection)

# %%
population
# Out:
#          county  year  overdose_deaths  population
# 0      ANDERSON  2018               18     75538.0
# 1      ANDERSON  2017               34     75538.0
# 2      ANDERSON  2016               24     75538.0
# 3      ANDERSON  2015               20     75538.0
# 4       BEDFORD  2018                7     46854.0
# ..          ...   ...              ...         ...
# 375  WILLIAMSON  2015               21    212161.0
# 376      WILSON  2018               19    128874.0
# 377      WILSON  2017               26    128874.0
# 378      WILSON  2016               27    128874.0
# 379      WILSON  2015               26    128874.0
#
# [380 rows x 4 columns]

# %%
database_name = 'ECD'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT county
	 , year
	 , ROUND(AVG(value), 3) AS unemployment_rate
	 , ROUND(AVG(population), 0) AS avg_population
FROM unemployment
	INNER JOIN population
		USING(year, county)
GROUP BY county, year
'''

with engine.connect() as connection:
    result = connection.execute(text(query))
    
with engine.connect() as connection:
    unemployment = pd.read_sql(text(query), con = connection)

# %%
unemployment
# Out:
#         county  year  unemployment_rate  avg_population
# 0      Hamblen  2013             11.075         62997.0
# 1        Macon  2014              6.058         22937.0
# 2         Knox  2014              6.258        447939.0
# 3       Wilson  2011             11.617        116756.0
# 4     Marshall  2012             10.933         30915.0
# ..         ...   ...                ...             ...
# 660      Wayne  2011              9.933         16942.0
# 661  Humphreys  2013              9.300         18245.0
# 662    Weakley  2011             10.533         34855.0
# 663    Hickman  2013              7.800         24202.0
# 664       Lake  2011             12.417          7793.0
#
# [665 rows x 4 columns]

# %%
population_merge = pd.merge(left = population, right = unemployment, 
                    left_on = 'county', right_on = 'county')
population_merge.head(50)
# Out:
#      county  year_x  unemployment_rate_x  avg_population_x  year_y  \
# 0   Hamblen    2013               11.075           62997.0    2013
# 1   Hamblen    2013               11.075           62997.0    2013
# 2   Hamblen    2013               11.075           62997.0    2013
# 3   Hamblen    2013               11.075           62997.0    2013
# 4   Hamblen    2013               11.075           62997.0    2013
# 5   Hamblen    2013               11.075           62997.0    2013
# 6   Hamblen    2013               11.075           62997.0    2013
