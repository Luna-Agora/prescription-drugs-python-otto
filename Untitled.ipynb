# %%
from sqlalchemy import create_engine, text

# %%
database_name = 'perscribers'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
import pandas as pd
import numpy as np

# %%
query = '''
SELECT county
     , year
     , overdose_deaths
     , population
FROM population
INNER JOIN fips_county
	ON population.fipscounty::int = fips_county.fipscounty::int
INNER JOIN overdose_deaths
	ON population.fipscounty::int = overdose_deaths.fipscounty::int
WHERE year = '2015' OR year = '2016' OR year = '2017'
'''

with engine.connect() as connection:
    result = connection.execute(text(query))
    
with engine.connect() as connection:
    population = pd.read_sql(text(query), con = connection)

# %%
population['county'] = population['county'].str.title()
population['county'] = population['county'].str.replace(' ', '')
population.head(60)
# Out:
#         county  year  overdose_deaths  population
# 0     Anderson  2017               34     75538.0
# 1     Anderson  2016               24     75538.0
# 2     Anderson  2015               20     75538.0
# 3      Bedford  2017                3     46854.0
# 4      Bedford  2016                1     46854.0
# 5      Bedford  2015                8     46854.0
# 6       Benton  2017                5     16154.0
# 7       Benton  2016                1     16154.0
# 8       Benton  2015                4     16154.0
# 9      Bledsoe  2017                2     14413.0
# 10     Bledsoe  2016                2     14413.0
# 11     Bledsoe  2015                1     14413.0
# 12      Blount  2017               29    127135.0
# 13      Blount  2016               21    127135.0
# 14      Blount  2015               19    127135.0
# 15     Bradley  2017               14    103666.0
# 16     Bradley  2016                7    103666.0
# 17     Bradley  2015               10    103666.0
# 18    Campbell  2017                5     39824.0
# 19    Campbell  2016                4     39824.0
# 20    Campbell  2015               16     39824.0
# 21      Cannon  2017                3     13839.0
# 22      Cannon  2016                3     13839.0
# 23      Cannon  2015                3     13839.0
# 24     Carroll  2017                2     28137.0
# 25     Carroll  2016                1     28137.0
# 26     Carroll  2015                1     28137.0
# 27      Carter  2017               16     56500.0
# 28      Carter  2016               14     56500.0
# 29      Carter  2015               10     56500.0
# 30    Cheatham  2017               24     39713.0
# 31    Cheatham  2016               13     39713.0
# 32    Cheatham  2015               15     39713.0
# 33     Chester  2017                1     17097.0
# 34     Chester  2016                2     17097.0
# 35     Chester  2015                3     17097.0
# 36   Claiborne  2017                2     31566.0
# 37   Claiborne  2016                2     31566.0
# 38   Claiborne  2015                3     31566.0
# 39        Clay  2017                2      7684.0
# 40        Clay  2016                6      7684.0
# 41        Clay  2015                2      7684.0
# 42       Cocke  2017                6     35262.0
# 43       Cocke  2016                4     35262.0
# 44       Cocke  2015                5     35262.0
# 45      Coffee  2017               12     54074.0
# 46      Coffee  2016               12     54074.0
# 47      Coffee  2015                8     54074.0
# 48    Crockett  2017                0     14554.0
# 49    Crockett  2016                0     14554.0
# 50    Crockett  2015                1     14554.0
# 51  Cumberland  2017                9     58178.0
# 52  Cumberland  2016                6     58178.0
# 53  Cumberland  2015                2     58178.0
# 54    Davidson  2017              184    678322.0
# 55    Davidson  2016              178    678322.0
# 56    Davidson  2015              127    678322.0
# 57     Decatur  2017                0     11681.0
# 58     Decatur  2016                3     11681.0
# 59     Decatur  2015                5     11681.0

# %%
database_name = 'ECD'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT county
	 , year
	 , ROUND(AVG(value), 3) AS unemployment_rate
	 , ROUND(AVG(population), 0) AS avg_population
FROM unemployment
	INNER JOIN population
		USING(year, county)
WHERE year = '2015' OR year = '2016' OR year = '2017'
GROUP BY year, county
'''

with engine.connect() as connection:
    result = connection.execute(text(query))
    
with engine.connect() as connection:
    unemployment = pd.read_sql(text(query), con = connection)

# %%
unemployment['county'] = unemployment['county'].str.title()
unemployment['county'] = unemployment['county'].str.replace(' ', '')
unemployment.head(20)
# Out:
#         county  year  unemployment_rate  avg_population
# 0      Houston  2017              4.158          8213.0
# 1        Scott  2016              4.850         21892.0
# 2       Putnam  2017              4.825         77674.0
# 3       Benton  2017              5.417         15986.0
# 4   Sequatchie  2017              3.967         14736.0
# 5         Knox  2016              4.333        456114.0
# 6        Lewis  2016              4.850         11912.0
# 7   Lauderdale  2017              4.033         25274.0
# 8     Sullivan  2015              7.908        156318.0
# 9      Hamblen  2017              5.217         64277.0
# 10       Lewis  2017              3.950         12035.0
# 11       Henry  2015              7.767         32145.0
# 12      Unicoi  2015              4.833         17779.0
# 13      Hardin  2016              3.958         25759.0
# 14      Blount  2015              5.175        126832.0
# 15   Humphreys  2015              7.067         18146.0
# 16    Lawrence  2017              4.558         43396.0
# 17       Meigs  2017              3.092         12068.0
# 18       Obion  2017              3.675         30385.0
# 19       Moore  2015              8.858          6256.0

# %%
unemployment['county'].sort_values()
unemployment
# Out:
#          county  year  unemployment_rate  avg_population
# 0       Houston  2017              4.158          8213.0
# 1         Scott  2016              4.850         21892.0
# 2        Putnam  2017              4.825         77674.0
# 3        Benton  2017              5.417         15986.0
# 4    Sequatchie  2017              3.967         14736.0
# ..          ...   ...                ...             ...
# 280      Tipton  2017              5.183         61366.0
# 281    Anderson  2015              5.825         75459.0
# 282    Hamilton  2017              3.567        361613.0
# 283  Lauderdale  2016              5.008         25350.0
# 284      Greene  2015              5.175         68500.0
#
# [285 rows x 4 columns]

# %%
population_merge = pd.merge(left = population, right = unemployment, 
                    left_on = 'county', right_on = 'county')
population_merge.head(50)
# Out:
#       county  year_x  overdose_deaths  population  year_y  unemployment_rate  \
# 0   Anderson    2017               34     75538.0    2017              3.950
# 1   Anderson    2017               34     75538.0    2016              4.850
# 2   Anderson    2017               34     75538.0    2015              5.825
# 3   Anderson    2016               24     75538.0    2017              3.950
# 4   Anderson    2016               24     75538.0    2016              4.850
# 5   Anderson    2016               24     75538.0    2015              5.825
# 6   Anderson    2015               20     75538.0    2017              3.950
# 7   Anderson    2015               20     75538.0    2016              4.850
# 8   Anderson    2015               20     75538.0    2015              5.825
# 9    Bedford    2017                3     46854.0    2016              4.942
# 10   Bedford    2017                3     46854.0    2017              3.967
# 11   Bedford    2017                3     46854.0    2015              6.433
# 12   Bedford    2016                1     46854.0    2016              4.942
# 13   Bedford    2016                1     46854.0    2017              3.967
# 14   Bedford    2016                1     46854.0    2015              6.433
# 15   Bedford    2015                8     46854.0    2016              4.942
# 16   Bedford    2015                8     46854.0    2017              3.967
# 17   Bedford    2015                8     46854.0    2015              6.433
# 18    Benton    2017                5     16154.0    2017              5.417
# 19    Benton    2017                5     16154.0    2016              7.092
# 20    Benton    2017                5     16154.0    2015              7.675
# 21    Benton    2016                1     16154.0    2017              5.417
# 22    Benton    2016                1     16154.0    2016              7.092
# 23    Benton    2016                1     16154.0    2015              7.675
# 24    Benton    2015                4     16154.0    2017              5.417
# 25    Benton    2015                4     16154.0    2016              7.092
# 26    Benton    2015                4     16154.0    2015              7.675
# 27   Bledsoe    2017                2     14413.0    2016              6.942
# 28   Bledsoe    2017                2     14413.0    2017              5.908
# 29   Bledsoe    2017                2     14413.0    2015              7.933
# 30   Bledsoe    2016                2     14413.0    2016              6.942
# 31   Bledsoe    2016                2     14413.0    2017              5.908
# 32   Bledsoe    2016                2     14413.0    2015              7.933
# 33   Bledsoe    2015                1     14413.0    2016              6.942
# 34   Bledsoe    2015                1     14413.0    2017              5.908
# 35   Bledsoe    2015                1     14413.0    2015              7.933
# 36    Blount    2017               29    127135.0    2015              5.175
# 37    Blount    2017               29    127135.0    2017              3.550
# 38    Blount    2017               29    127135.0    2016              4.358
# 39    Blount    2016               21    127135.0    2015              5.175
# 40    Blount    2016               21    127135.0    2017              3.550
# 41    Blount    2016               21    127135.0    2016              4.358
# 42    Blount    2015               19    127135.0    2015              5.175
# 43    Blount    2015               19    127135.0    2017              3.550
# 44    Blount    2015               19    127135.0    2016              4.358
# 45   Bradley    2017               14    103666.0    2017              3.675
# 46   Bradley    2017               14    103666.0    2016              4.450
# 47   Bradley    2017               14    103666.0    2015              5.250
# 48   Bradley    2016                7    103666.0    2017              3.675
# 49   Bradley    2016                7    103666.0    2016              4.450
#
#     avg_population
# 0          76257.0
# 1          75585.0
# 2          75459.0
# 3          76257.0
# 4          75585.0
# 5          75459.0
# 6          76257.0
# 7          75585.0
# 8          75459.0
# 9          47420.0
# 10         48117.0
# 11         46892.0
# 12         47420.0
# 13         48117.0
# 14         46892.0
# 15         47420.0
# 16         48117.0
# 17         46892.0
# 18         15986.0
# 19         16059.0
# 20         16192.0
# 21         15986.0
# 22         16059.0
# 23         16192.0
# 24         15986.0
# 25         16059.0
# 26         16192.0
# 27         14599.0
# 28         14717.0
# 29         14483.0
# 30         14599.0
# 31         14717.0
# 32         14483.0
# 33         14599.0
# 34         14717.0
# 35         14483.0
# 36        126832.0
# 37        129929.0
# 38        128244.0
# 39        126832.0
# 40        129929.0
# 41        128244.0
# 42        126832.0
# 43        129929.0
# 44        128244.0
# 45        105560.0
# 46        104407.0
# 47        103802.0
# 48        105560.0
# 49        104407.0

# %%
population_merge.shape
# Out:
# (828, 7)

# %%
index_names = population_merge[ (population_merge['year_x'] != population_merge['year_y'])].index
population_merge.drop(index_names, inplace = True)
print(population_merge)
# Out:
#          county  year_x  overdose_deaths  population  year_y  \
# 0      Anderson    2017               34     75538.0    2017
# 4      Anderson    2016               24     75538.0    2016
# 8      Anderson    2015               20     75538.0    2015
# 10      Bedford    2017                3     46854.0    2017
# 12      Bedford    2016                1     46854.0    2016
# ..          ...     ...              ...         ...     ...
# 814  Williamson    2016               19    212161.0    2016
# 818  Williamson    2015               21    212161.0    2015
# 821      Wilson    2017               26    128874.0    2017
# 823      Wilson    2016               27    128874.0    2016
# 825      Wilson    2015               26    128874.0    2015
#
#      unemployment_rate  avg_population
# 0                3.950         76257.0
# 4                4.850         75585.0
# 8                5.825         75459.0
# 10               3.967         48117.0
# 12               4.942         47420.0
# ..                 ...             ...
# 814              3.600        218888.0
# 818              4.392        211456.0
# 821              5.250        136442.0
# 823              6.858        132433.0
# 825              7.875        128434.0
#
# [276 rows x 7 columns]

# %%
population_merge
# Out:
#          county  year_x  overdose_deaths  population  year_y  \
# 0      Anderson    2017               34     75538.0    2017
# 4      Anderson    2016               24     75538.0    2016
# 8      Anderson    2015               20     75538.0    2015
# 10      Bedford    2017                3     46854.0    2017
# 12      Bedford    2016                1     46854.0    2016
# ..          ...     ...              ...         ...     ...
# 814  Williamson    2016               19    212161.0    2016
# 818  Williamson    2015               21    212161.0    2015
# 821      Wilson    2017               26    128874.0    2017
# 823      Wilson    2016               27    128874.0    2016
# 825      Wilson    2015               26    128874.0    2015
#
#      unemployment_rate  avg_population
# 0                3.950         76257.0
# 4                4.850         75585.0
# 8                5.825         75459.0
# 10               3.967         48117.0
# 12               4.942         47420.0
# ..                 ...             ...
# 814              3.600        218888.0
# 818              4.392        211456.0
# 821              5.250        136442.0
# 823              6.858        132433.0
# 825              7.875        128434.0
#
# [276 rows x 7 columns]

# %%
population_merge = population_merge.reset_index()

# %%
population_merge = population_merge.drop(columns=['year_y', 'avg_population'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 population_merge = population_merge.drop(columns=['year_y', 'avg_population'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['year_y', 'avg_population'] not found in axis"

# %%
population_merge
# Out:
#          county  year_x  overdose_deaths  population  unemployment_rate
# 0      Anderson    2017               34     75538.0              3.950
# 4      Anderson    2016               24     75538.0              4.850
# 8      Anderson    2015               20     75538.0              5.825
# 10      Bedford    2017                3     46854.0              3.967
# 12      Bedford    2016                1     46854.0              4.942
# ..          ...     ...              ...         ...                ...
# 814  Williamson    2016               19    212161.0              3.600
# 818  Williamson    2015               21    212161.0              4.392
# 821      Wilson    2017               26    128874.0              5.250
# 823      Wilson    2016               27    128874.0              6.858
# 825      Wilson    2015               26    128874.0              7.875
#
# [276 rows x 5 columns]

# %%
population_merge = population_merge.drop(columns=['population'])

# %%
population_merge.head(60)
# Out:
#     index      county  year_x  overdose_deaths  unemployment_rate
# 0       0    Anderson    2017               34              3.950
# 1       4    Anderson    2016               24              4.850
# 2       8    Anderson    2015               20              5.825
# 3      10     Bedford    2017                3              3.967
# 4      12     Bedford    2016                1              4.942
# 5      17     Bedford    2015                8              6.433
# 6      18      Benton    2017                5              5.417
# 7      22      Benton    2016                1              7.092
# 8      26      Benton    2015                4              7.675
# 9      28     Bledsoe    2017                2              5.908
# 10     30     Bledsoe    2016                2              6.942
# 11     35     Bledsoe    2015                1              7.933
# 12     37      Blount    2017               29              3.550
# 13     41      Blount    2016               21              4.358
# 14     42      Blount    2015               19              5.175
# 15     45     Bradley    2017               14              3.675
# 16     49     Bradley    2016                7              4.450
# 17     53     Bradley    2015               10              5.250
# 18     54    Campbell    2017                5              5.217
# 19     58    Campbell    2016                4              6.883
# 20     62    Campbell    2015               16              7.908
# 21     65      Cannon    2017                3              3.567
# 22     66      Cannon    2016                3              4.608
# 23     70      Cannon    2015                3              5.783
# 24     72     Carroll    2017                2              5.183
# 25     77     Carroll    2016                1              6.700
# 26     79     Carroll    2015                1              8.275
# 27     81      Carter    2017               16              4.567
# 28     86      Carter    2016               14              5.633
# 29     88      Carter    2015               10              6.442
# 30     92    Cheatham    2017               24              3.092
# 31     93    Cheatham    2016               13              3.958
# 32     97    Cheatham    2015               15              4.833
# 33    101     Chester    2017                1              3.992
# 34    102     Chester    2016                2              4.942
# 35    106     Chester    2015                3              5.867
# 36    109   Claiborne    2017                2              4.758
# 37    113   Claiborne    2016                2              6.192
# 38    114   Claiborne    2015                3              7.233
# 39    118        Clay    2017                2              5.158
# 40    122        Clay    2016                6              6.550
# 41    123        Clay    2015                2              8.858
# 42    126       Cocke    2017                6              5.275
# 43    130       Cocke    2016                4              6.300
# 44    134       Cocke    2015                5              7.767
# 45    135      Coffee    2017               12              3.675
# 46    140      Coffee    2016               12              4.675
# 47    142      Coffee    2015                8              5.508
# 48    145    Crockett    2017                0              4.158
# 49    147    Crockett    2016                0              5.217
# 50    152    Crockett    2015                1              6.417
# 51    153  Cumberland    2017                9              4.667
# 52    157  Cumberland    2016                6              5.908
# 53    161  Cumberland    2015                2              7.067
# 54    163    Davidson    2017              184              2.817
# 55    167    Davidson    2016              178              3.600
# 56    168    Davidson    2015              127              4.392
# 57    172     Decatur    2017                0              5.250
# 58    174     Decatur    2016                3              6.858
# 59    179     Decatur    2015                5              7.875

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
population_merge.shape
# Out:
# (276, 5)

# %%
pd.crosstab(population_merge['overdose_deaths'], population_merge['unemployment_rate']).plot(kind = 'bar', 
                                                          stacked = True, 
                                                          color = ['cornflowerblue', 'coral', 'pink'],
                                                          edgecolor = 'black')
plt.title('overdose vs unemployment')
plt.xticks(rotation = 0);

# %%
population_merge.plot(kind = 'scatter',
             x = 'overdose_deaths',
             y = 'unemployment_rate',
             figsize = (10,6));

# %%
population_merge.corr(numeric_only = True)
# Out:
#                       index    year_x  overdose_deaths  unemployment_rate
# index              1.000000 -0.010396         0.031866           0.007556
# year_x            -0.010396  1.000000         0.036620          -0.671849
# overdose_deaths    0.031866  0.036620         1.000000          -0.097127
# unemployment_rate  0.007556 -0.671849        -0.097127           1.000000
